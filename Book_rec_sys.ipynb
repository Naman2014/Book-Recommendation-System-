# %%
import pandas as pd
import numpy as np
import sys

if not sys.warnoptions:
    import warnings
    warnings.simplefilter("ignore")

# %%
books= pd.read_csv('Books.csv')

# %%
users= pd.read_csv('Users.csv')

# %%
ratings= pd.read_csv('Ratings.csv')

# %%
books
# Out:
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                  Book-Author Year-Of-Publication  \
# 0         Mark P. O. Morford                2002
# ...

# %%
users
# Out:
#         User-ID                            Location   Age
# 0             1                  nyc, new york, usa   NaN
# 1             2           stockton, california, usa  18.0
# 2             3     moscow, yukon territory, russia   NaN
# 3             4           porto, v.n.gaia, portugal  17.0
# 4             5  farnborough, hants, united kingdom   NaN
# ...         ...                                 ...   ...
# 278853   278854               portland, oregon, usa   NaN
# 278854   278855  tacoma, washington, united kingdom  50.0
# 278855   278856           brampton, ontario, canada   NaN
# 278856   278857           knoxville, tennessee, usa   NaN
# 278857   278858                dublin, n/a, ireland   NaN
#
# [278858 rows x 3 columns]

# %%
ratings
# Out:
#          User-ID         ISBN  Book-Rating
# 0         276725   034545104X            0
# 1         276726   0155061224            5
# 2         276727   0446520802            0
# 3         276729   052165615X            3
# 4         276729   0521795028            6
# ...          ...          ...          ...
# 1149775   276704   1563526298            9
# 1149776   276706   0679447156            0
# 1149777   276709   0515107662           10
# 1149778   276721   0590442449           10
# 1149779   276723  05162443314            8
#
# [1149780 rows x 3 columns]

# %%
print(books.shape)
print(ratings.shape)
print(users.shape)
# Out:
# (271360, 8)
# (1149780, 3)
# (278858, 3)

# %%
books.isnull().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            1
# Year-Of-Publication    0
# Publisher              2
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            3
# dtype: int64

# %%
ratings.isnull().sum()
# Out:
# User-ID        0
# ISBN           0
# Book-Rating    0
# dtype: int64

# %%
users.isnull().sum()
# Out:
# User-ID          0
# Location         0
# Age         110762
# dtype: int64

# %%
x= books.duplicated().sum()
y= ratings.duplicated().sum()
z= users.duplicated().sum()
print(x,y,z)
# Out:
# 0 0 0

# %% [markdown]
# Observations
# From above we get to know that data is almost clean. We have null only in Age column of users that will not be needed.
# And along with this we don't have duplicates.
# In books dataset, we have 6 nulls so we will discard those. Also that won't affect too much but still we will remove.

# %%
books= books.dropna()

# %%
books
# Out:
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                  Book-Author Year-Of-Publication  \
# 0         Mark P. O. Morford                2002
# ...

# %%
books.reset_index(inplace=True)
books
# Out:
#         level_0   index        ISBN  \
# 0             0       0  0195153448
# 1             1       1  0002005018
# 2             2       2  0060973129
# 3             3       3  0374157065
# 4             4       4  0393045218
# ...         ...     ...         ...
# 271349   271349  271355  0440400988
# 271350   271350  271356  0525447644
# 271351   271351  271357  006008667X
# 271352   271352  271358  0192126040
# 271353   271353  271359  0767409752
#
#                                                Book-Title  \
# 0                                     Classical Mythology
# 1                                            Clara Callan
# 2                                    Decision in Normandy
# 3       Flu: The Story of the Great Influenza Pandemic...
# 4                                  The Mummies of Urumchi
# ...                                                   ...
# 271349                         There's a Bat in Bunk Five
# ...

# %%
books.drop(columns=["level_0","index","Image-URL-S","Image-URL-M","Image-URL-L"],inplace=True)
books
# Out:
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271349  0440400988                         There's a Bat in Bunk Five
# 271350  0525447644                            From One to One Hundred
# 271351  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271352  0192126040                        Republic (World's Classics)
# 271353  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                  Book-Author Year-Of-Publication  \
# 0         Mark P. O. Morford                2002
# ...

# %% [markdown]
# # Popularity Based Recommendation system

# %%
ratings_new = ratings.merge(books,on='ISBN')

# %%
ratings_new
# Out:
#          User-ID        ISBN  Book-Rating  \
# 0         276725  034545104X            0
# 1           2313  034545104X            5
# 2           6543  034545104X            0
# 3           8680  034545104X            5
# 4          10314  034545104X            9
# ...          ...         ...          ...
# 1031124   276688  0517145553            0
# 1031125   276688  1575660792            7
# 1031126   276690  0590907301            0
# 1031127   276704  0679752714            0
# 1031128   276704  0806917695            5
#
#                                                 Book-Title      Book-Author  \
# 0                                     Flesh Tones: A Novel       M. J. Rose
# 1                                     Flesh Tones: A Novel       M. J. Rose
# 2                                     Flesh Tones: A Novel       M. J. Rose
# 3                                     Flesh Tones: A Novel       M. J. Rose
# ...

# %%
num_rating_df = ratings_new.groupby('Book-Title').count()['Book-Rating'].reset_index()
num_rating_df.rename(columns={'Book-Rating':'num_ratings'},inplace=True)
num_rating_df
# Out:
#                                                Book-Title  num_ratings
# 0        A Light in the Storm: The Civil War Diary of ...            4
# 1                                   Always Have Popsicles            1
# 2                    Apple Magic (The Collector's series)            1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...            1
# 4        Beyond IBM: Leadership Marketing and Finance ...            1
# ...                                                   ...          ...
# 241061                                      Ã?Â?lpiraten.            2
# 241062                     Ã?Â?rger mit Produkt X. Roman.            4
# 241063                                Ã?Â?sterlich leben.            1
# 241064                              Ã?Â?stlich der Berge.            3
# 241065                                  Ã?Â?thique en toc            2
#
# [241066 rows x 2 columns]

# %%
avg_rating_df = ratings_new.groupby('Book-Title').mean()['Book-Rating'].reset_index()
avg_rating_df.rename(columns={'Book-Rating':'avg_rating'},inplace=True)
avg_rating_df
# Out:
#                                                Book-Title  avg_rating
# 0        A Light in the Storm: The Civil War Diary of ...    2.250000
# 1                                   Always Have Popsicles    0.000000
# 2                    Apple Magic (The Collector's series)    0.000000
# 3        Ask Lily (Young Women of Faith: Lily Series, ...    8.000000
# 4        Beyond IBM: Leadership Marketing and Finance ...    0.000000
# ...                                                   ...         ...
# 241061                                      Ã?Â?lpiraten.    0.000000
# 241062                     Ã?Â?rger mit Produkt X. Roman.    5.250000
# 241063                                Ã?Â?sterlich leben.    7.000000
# 241064                              Ã?Â?stlich der Berge.    2.666667
# 241065                                  Ã?Â?thique en toc    4.000000
#
# [241066 rows x 2 columns]

# %%
popular_df = num_rating_df.merge(avg_rating_df,on='Book-Title')
popular_df
# Out:
#                                                Book-Title  num_ratings  \
# 0        A Light in the Storm: The Civil War Diary of ...            4
# 1                                   Always Have Popsicles            1
# 2                    Apple Magic (The Collector's series)            1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...            1
# 4        Beyond IBM: Leadership Marketing and Finance ...            1
# ...                                                   ...          ...
# 241061                                      Ã?Â?lpiraten.            2
# 241062                     Ã?Â?rger mit Produkt X. Roman.            4
# 241063                                Ã?Â?sterlich leben.            1
# 241064                              Ã?Â?stlich der Berge.            3
# 241065                                  Ã?Â?thique en toc            2
#
#         avg_rating
# 0         2.250000
# 1         0.000000
# 2         0.000000
# 3         8.000000
# ...

# %%
popular_df = popular_df[popular_df['num_ratings']>=250].sort_values('avg_rating',ascending=False).head(50)

# %%
popular_df
# Out:
#                                                Book-Title  num_ratings  \
# 80432   Harry Potter and the Prisoner of Azkaban (Book 3)          428
# 80420        Harry Potter and the Goblet of Fire (Book 4)          387
# 80439      Harry Potter and the Sorcerer's Stone (Book 1)          278
# 80424   Harry Potter and the Order of the Phoenix (Boo...          347
# 80412    Harry Potter and the Chamber of Secrets (Book 2)          556
# 191608  The Hobbit : The Enchanting Prelude to The Lor...          281
# 187373  The Fellowship of the Ring (The Lord of the Ri...          368
# 80443   Harry Potter and the Sorcerer's Stone (Harry P...          575
# 211380     The Two Towers (The Lord of the Rings, Part 2)          260
# 219737                              To Kill a Mockingbird          510
# 183569                                  The Da Vinci Code          898
# 187876                 The Five People You Meet in Heaven          430
# ...

# %%
# for most viewed option
most_viewed = num_rating_df.sort_values('num_ratings', ascending=False).head(50)

# %%
most_viewed
# Out:
#                                                Book-Title  num_ratings
# 234946                                        Wild Animus         2502
# 196322                          The Lovely Bones: A Novel         1295
# 183569                                  The Da Vinci Code          898
# 5303                                      A Painted House          838
# 199233                         The Nanny Diaries: A Novel          828
# 27922                               Bridget Jones's Diary          815
# 206498                            The Secret Life of Bees          774
# 52981     Divine Secrets of the Ya-Ya Sisterhood: A Novel          740
# 204383                The Red Tent (Bestselling Backlist)          723
# 14392                                 Angels &amp; Demons          670
# 107960                                         Life of Pi          664
# 162648                             Snow Falling on Cedars          662
# ...

# %% [markdown]
# # Collaborative Filtering Based Recommender System (USER BASED )

# %%
# extracting users which gave 200+ ratings and it means they are regular users
x = ratings_new.groupby('User-ID').count()['Book-Rating'] > 200
reg_user = x[x].index

# %%
filtered_rating = ratings_new[ratings_new['User-ID'].isin(reg_user)]

# %%
# extracting books that have received more than 50 ratings and it means those are famous ones
y = filtered_rating.groupby('Book-Title').count()['Book-Rating']>=50
famous_books = y[y].index

# %%
final_ratings = filtered_rating[filtered_rating['Book-Title'].isin(famous_books)]

# %%
# creating a pivot table that will have Book-title as index and user-id as columns and book rating as values
pt = final_ratings.pivot_table(index='Book-Title',columns='User-ID',values='Book-Rating')
pt.fillna(0,inplace=True)
pt
# Out:
# User-ID                                             254     2276    2766    \
# Book-Title
# 1984                                                   9.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0    10.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     7.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# ...

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity_scores = cosine_similarity(pt)
similarity_scores.shape
# Out:
# (706, 706)

# %%
def recommend(book_name):
    # index fetch
    index = np.where(pt.index == book_name)[0][0]
    
    # sorting out top 4 similarity scores
    similar_items = sorted(list(enumerate(similarity_scores[index])), key=lambda x: x[1], reverse=True)[1:5]
    
    data = []
    for i in similar_items:
        item = []
        temp_df = books[books['Book-Title'] == pt.index[i[0]]]
        book_titles = ['{} by {}'.format(title, author) for title, author in zip(temp_df.drop_duplicates('Book-Title')['Book-Title'].values, temp_df.drop_duplicates('Book-Title')['Book-Author'].values)]
        item.extend(book_titles)
        
        data.append(item)
    
    # Printing the books similar to the specified book
    print(f"Books similar to {book_name} are:")
    for item in data:
        print(item)

# %%
# recommending a book by taking input
bk= input("Enter book name\n")
# Out:
# Enter book name
# 1984

# %%
recommend(bk)
# Out:
# Books similar to 1984 are:
# ['Animal Farm by George Orwell']
# ["The Handmaid's Tale by Margaret Atwood"]
# ['Brave New World by Aldous Huxley']
# ['The Vampire Lestat (Vampire Chronicles, Book II) by ANNE RICE']
